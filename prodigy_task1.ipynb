# %%
# !pip install pandas matplotlib

# %%
import zipfile
import pandas as pd

# Unzip the dataset
with zipfile.ZipFile('API_SP.POP.TOTL_DS2_en_csv_v2_1114030.zip', 'r') as zip_ref:
    zip_ref.extractall('world_population')

# Load the CSV file
csv_file_path = 'world_population/API_SP.POP.TOTL_DS2_en_csv_v2_1114030.csv'
data = pd.read_csv(csv_file_path, skiprows=4)  # Skipping the first 4 rows

# %%
data.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2015         2016         2017         2018  \
# ...

# %%
# Extract population data for the year 2023
population_2023 = data[['Country Name', '2023']].dropna()

# Sort the data by population in descending order
population_2023_sorted = population_2023.sort_values(by='2023', ascending=False)

# %%
import matplotlib.pyplot as plt

# Plotting the data
plt.figure(figsize=(10, 6))
plt.bar(population_2023_sorted['Country Name'][:10], population_2023_sorted['2023'][:10])
plt.xlabel('Country')
plt.ylabel('Population in 2023')
plt.title('Top 10 Countries by Population in 2023')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Show the plot
plt.show()

# %%
import zipfile
import pandas as pd
import matplotlib.pyplot as plt

# Unzip the dataset
with zipfile.ZipFile('API_SP.POP.TOTL_DS2_en_csv_v2_1114030.zip', 'r') as zip_ref:
    zip_ref.extractall('world_population')

# Load the CSV file
csv_file_path = 'world_population/API_SP.POP.TOTL_DS2_en_csv_v2_1114030.csv'
data = pd.read_csv(csv_file_path, skiprows=4)  # Skipping the first 4 rows

# Inspect the data
print(data.head())

# Extract population data for the year 2023
population_2023 = data[['Country Name', '2023']].dropna()

# Sort the data by population in descending order
population_2023_sorted = population_2023.sort_values(by='2023', ascending=False)

# Plotting the data
plt.figure(figsize=(10, 6))
plt.bar(population_2023_sorted['Country Name'][:10], population_2023_sorted['2023'][:10])
plt.xlabel('Country')
plt.ylabel('Population in 2023')
plt.title('Top 10 Countries by Population in 2023')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Show the plot
plt.show()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2015         2016         2017         2018  \
# ...
